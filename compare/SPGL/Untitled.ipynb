# %%
# !PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True python main.py --dataset Nowplaying --batchSize 2
# Out:
# Namespace(dataset='Nowplaying', epoch=30, batchSize=2, embSize=100, l2=1e-05, lr=0.001, layer=5, temperature=0.1, item_cl_loss_weight=1, sampled_item_size=35000, top_k=50, hoplimit=3, seed=42)
